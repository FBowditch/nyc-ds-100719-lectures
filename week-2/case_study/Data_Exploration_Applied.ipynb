# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#Load our dataframe account for the index columns
df = pd.read_csv('case_study.csv', index_col = 0)
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (171) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Quickly check to see the size of our DF, both rows and columns
df.shape
# Out:
# (34545, 358)

# %%
df.shape

df.head()
# Out:
#        _STATE  FMONTH    IDATE  IMONTH  IDAY  IYEAR  DISPCODE       SEQNO  \
# 49938     9.0     5.0  5172017       5    17   2017    1200.0  2017000001
# 49939     9.0     2.0  2142017       2    14   2017    1200.0  2017000002
# 49940     9.0     1.0  1292017       1    29   2017    1200.0  2017000003
# 49941     9.0     7.0  9112017       9    11   2017    1200.0  2017000004
# 49942     9.0     5.0  7182017       7    18   2017    1200.0  2017000005
#
#                _PSU  CTELENM1  ...  _PA300R2  _PA30021  _PASTRNG  _PAREC1  \
# 49938  2.017000e+09       NaN  ...       2.0       2.0       2.0      4.0
# 49939  2.017000e+09       NaN  ...       1.0       1.0       1.0      1.0
# 49940  2.017000e+09       NaN  ...       3.0       2.0       1.0      3.0
# 49941  2.017000e+09       NaN  ...       2.0       2.0       2.0      2.0
# 49942  2.017000e+09       NaN  ...       2.0       2.0       1.0      1.0
#
#        _PASTAE1  _RFSEAT2  _RFSEAT3  _FLSHOT6  _PNEUMO2  _AIDTST3
# ...

# %% [markdown]
# ## Subset your dataframe to only include the states in the tri-state area (NJ, CT, NY)

# %%
tristates = [9,34,36]
df = df[df['_STATE'].isin(tristates)]

df

df['_STATE'].replace({ 9 : 'CT', 34 : 'NJ', 36 : 'NY'}, inplace=True)

df
# Out:
#        _STATE  FMONTH     IDATE  IMONTH  IDAY  IYEAR  DISPCODE       SEQNO  \
# 49938      CT     5.0   5172017       5    17   2017    1200.0  2017000001
# 49939      CT     2.0   2142017       2    14   2017    1200.0  2017000002
# 49940      CT     1.0   1292017       1    29   2017    1200.0  2017000003
# 49941      CT     7.0   9112017       9    11   2017    1200.0  2017000004
# 49942      CT     5.0   7182017       7    18   2017    1200.0  2017000005
# 49943      CT     1.0   1192017       1    19   2017    1100.0  2017000006
# 49944      CT     1.0   2032017       2     3   2017    1100.0  2017000007
# 49945      CT     1.0   2012017       2     1   2017    1100.0  2017000008
# 49946      CT     1.0   1262017       1    26   2017    1100.0  2017000009
# 49947      CT     1.0   1192017       1    19   2017    1100.0  2017000010
# 49948      CT     1.0   1242017       1    24   2017    1100.0  2017000011
# ...

# %% [markdown]
# Now check to see how large our subset df.

# %%
df.head()# your code here
# Out:
#       _STATE  FMONTH    IDATE  IMONTH  IDAY  IYEAR  DISPCODE       SEQNO  \
# 49938     CT     5.0  5172017       5    17   2017    1200.0  2017000001
# 49939     CT     2.0  2142017       2    14   2017    1200.0  2017000002
# 49940     CT     1.0  1292017       1    29   2017    1200.0  2017000003
# 49941     CT     7.0  9112017       9    11   2017    1200.0  2017000004
# 49942     CT     5.0  7182017       7    18   2017    1200.0  2017000005
#
#                _PSU  CTELENM1  ...  _PA300R2  _PA30021  _PASTRNG  _PAREC1  \
# 49938  2.017000e+09       NaN  ...       2.0       2.0       2.0      4.0
# 49939  2.017000e+09       NaN  ...       1.0       1.0       1.0      1.0
# 49940  2.017000e+09       NaN  ...       3.0       2.0       1.0      3.0
# 49941  2.017000e+09       NaN  ...       2.0       2.0       2.0      2.0
# 49942  2.017000e+09       NaN  ...       2.0       2.0       1.0      1.0
#
#        _PASTAE1  _RFSEAT2  _RFSEAT3  _FLSHOT6  _PNEUMO2  _AIDTST3
# ...

# %% [markdown]
# **PHYSHLTH** is the column we are interested in for this analysis, so let's start to investigate the column. Since we have a data cookbook, a.k.a. data dictionary) we want to start there before looking at the code.

# %%
df['PHYSHLTH'].describe()
# Out:
# count    34545.000000
# mean        60.213403
# std         37.504566
# min          1.000000
# 25%         15.000000
# 50%         88.000000
# 75%         88.000000
# max         99.000000
# Name: PHYSHLTH, dtype: float64

# %% [markdown]
# ## 1. Handle the non-normal values
#
# As you can see from the data dictionary, there are a number of responses that are coded with values that could throw off our descriptive statistics.  Let's clean up by mapping the responses to a more appropriate value, and handling any missing values.

# %%
zero_dict = {88:0,
            77: np.nan,
            99: np.nan}

df['PHYSHLTH'] = df['PHYSHLTH'].replace(zero_dict)

df['PHYSHLTH'].describe()
# Out:
# count    33747.000000
# mean         4.085341
# std          8.513293
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          3.000000
# max         30.000000
# Name: PHYSHLTH, dtype: float64

# %% [markdown]
# ## 2. Generate the descriptive statistics
#
# Now that our target variable is cleaned up lets calculate the descriptive statistics, generate a graph that quickly shows those statistics, and generate a gprah shows the histogram of the data.

# %%
physhlth_stats = df['PHYSHLTH'].describe()
physhlth_stats = physhlth_stats.drop('count')
physhlth_stats
# Out:
# mean     4.085341
# std      8.513293
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      3.000000
# max     30.000000
# Name: PHYSHLTH, dtype: float64

# %%
physhlth_stats.plot.box(title = "Physhealth Stats")

# %%
plt.hist(physhlth_stats)

df.columns
# Out:
# Index(['_STATE', 'FMONTH', 'IDATE', 'IMONTH', 'IDAY', 'IYEAR', 'DISPCODE',
#        'SEQNO', '_PSU', 'CTELENM1',
#        ...
#        '_PA300R2', '_PA30021', '_PASTRNG', '_PAREC1', '_PASTAE1', '_RFSEAT2',
#        '_RFSEAT3', '_FLSHOT6', '_PNEUMO2', '_AIDTST3'],
#       dtype='object', length=358)

# %%
# graphic showing the distribution of data

# %% [markdown]
# ## 3. Generate a graphic that compares the average number of sick days for each state.

# %%
df.groupby('_STATE')['PHYSHLTH'].mean()

avg_sick = df.groupby('_STATE')['PHYSHLTH'].mean()

# x = {'9.0': 'CT', '34.0': 'NJ', '36.0': 'NY'}

# for x in df.columns():
#     df['_STATE'] = df['_STATE'].map(x)

# code to calculate the average number of sick days by state

# %%
avg_sick.plot.bar(title = 'avg by state')# code to graph those averages using matplotlib

# %% [markdown]
# ## 4. Turn the number of sick days into a classification of of chronically sick people.
#
# Chronically sick people account for a significant proportion of the costs for health insurers. If we can identify what leads people to be chronically sick, we can address them with specific treatments.

# %%
df['Chronically_Sick'] = list(map(lambda x: 1 if x > 14 else 0, df['PHYSHLTH']))                            

df['Chronically_Sick']



#df['Chronically_Sick'] = np.where(df['PHYSHLTH']>=14, 1, 0)
# Out:
# 49938     0
# 49939     0
# 49940     0
# 49941     0
# 49942     0
# 49943     0
# 49944     0
# 49945     0
# 49946     1
# 49947     0
# 49948     0
# 49949     0
# 49950     0
# 49951     0
# 49952     0
# 49953     0
# 49954     0
# 49955     1
# 49956     0
# 49957     0
# 49958     0
# 49959     0
# 49960     0
# 49961     0
# 49962     0
# 49963     0
# 49964     0
# 49965     0
# 49966     0
# 49967     0
#          ..
# 303749    0
# 303750    0
# 303751    1
# 303752    0
# 303753    0
# 303754    0
# 303755    0
# 303756    0
# 303757    0
# 303758    0
# 303759    0
# 303760    0
# 303761    0
# 303762    0
# 303763    1
# 303764    0
# 303765    0
# 303766    0
# 303767    0
# 303768    0
# 303769    0
# 303770    0
# 303771    0
# 303772    0
# 303773    0
# 303774    0
# 303775    0
# 303776    0
# 303777    0
# 303778    0
# Name: Chronically_Sick, Length: 34545, dtype: int64

# %% [markdown]
# ## 5. Create a graphic that compares the percentage of people labeled as 'sick' in each state.

# %%
perc_sick_state = pd.crosstab(df['_STATE'],df['Chronically_Sick']).apply(lambda r: r/r.sum(), axis=1)

# %%
perc_sick_state.plot.bar(stacked=True)# create graphic to compare chronically sick by state

# %% [markdown]
# ## 6. Independent Variables (categorical)
#
# Let's take the column `SMOKDAY2` and start to prepare it so that we can see how it is possibly correlated to `PHYSHLTH`.
#
# 1. Clean up the values.
# 2. Calculate the descriptive statistics of the variable.
# 3. Generate a histogram for the variable.
# 4. Generate graphics that show how the responses to this variable might differ by state.
# 5. Generate a graphic that compares the physical health of the different groups of 'smokers'.

# %%
smok_dict = {1:'Every Day',
            2: 'Somedays',
            3: 'Not at all'}

df['SMOKDAY2'].replace(smok_dict, inplace=True)

df.drop(df.loc[df['SMOKDAY2']==7].index, inplace=True)
df.drop(df.loc[df['SMOKDAY2']==9].index, inplace=True)

df['SMOKDAY2'].fillna('Not at all', inplace=True)

smokday2_stats = df['SMOKDAY2'].value_counts()

# %%
smokday2_stats = df['SMOKDAY2'].value_counts()
smokday2_stats


smokday2_stats.plot.bar()

# %%
state_smoke = pd.DataFrame(df.groupby('_STATE')['SMOKDAY2'].value_counts())

# %%
state_smoke.plot.bar()

# %%
smoke_health = pd.DataFrame(df.groupby('SMOKDAY2')['PHYSHLTH'].mean())

# %%
smoke_health.plot.bar()

# %% [markdown]
# ## 7. Independent Variables (continuous):
#
# Now let's look at a continuous variable (ALCDAY5) and see how that might impact a person's health.
#
# 1. Clean up the values.
# 2. Calculate the descriptive statistics of the variable.
# 3. Generate a histogram for the variable.
# 4. Generate graphics that show how the responses to this variable might differ by state.
# 5. Calculate the correlation coefficient between `PHYSHLTH` and `ALCDAY5`.
# 5. Generate a graphic that shows the possible relationship between `PHYSHLTH` and `ALCDAY5`.

# %%
# alc_dict = {1:'Every Day',
#             2: 'Somedays',
#             3: 'Not at all'}

# df['SMOKDAY2'].replace(smok_dict, inplace=True)


# df['SMOKDAY2'].fillna('Not at all', inplace=True)

# smokday2_stats = df['SMOKDAY2'].value_counts()

# %%
def drinks_p_month(num):
        num1 = int(num)
        if num1 <200:
            days_per_month = int(str(num1)[-1])*4
            return days_per_month
        elif num1 >200 and num1 <300:
            days_per_month1 = int(str(num1)[-2:])
            return days_per_month1
        else:
            return 0
        
        
#         if x >200:
#             return x - 200
#         elif x>100:
#             return (x -100)*4
#         else:
#             return x

# %%
df.drop(df.loc[df['ALCDAY5']==999].index, inplace=True)
df.drop(df.loc[df['ALCDAY5']==777].index, inplace=True)
df['ALCDAY5'].dropna(inplace=True)

# 888:0
# 777:np.nan
#     999:np.nan

# %%
df['Newalc'] = df['ALCDAY5'].apply(drinks_p_month)

# %%
df['Newalc'].describe()
# Out:
# count    32188.000000
# mean         5.296539
# std          8.176435
# min          0.000000
# 25%          0.000000
# 50%          2.000000
# 75%          7.000000
# max         30.000000
# Name: Newalc, dtype: float64

# %%
new_alc = df['Newalc'].value_counts()


new_alc

# %%
drink_health = pd.DataFrame(df.groupby('Newalc')['PHYSHLTH'])# your code here PHYSHLTH

import seaborn as sns

sns.scatterplot(x = df['Newalc'], y = df['PHYSHLTH'])

df['Newalc'].value_counts()
# Out:
# 0.0     13031
# 1.0      3025
# 4.0      2739
# 2.0      2322
# 8.0      1600
# 3.0      1349
# 30.0     1163
# 5.0      1155
# 20.0     1001
# 12.0      924
# 10.0      840
# 28.0      766
# 15.0      590
# 16.0      401
# 6.0       389
# 7.0       278
# 25.0      265
# 24.0      123
# 14.0       53
# 29.0       31
# 9.0        28
# 27.0       24
# 18.0       19
# 26.0       15
# 22.0       13
# 21.0       13
# 13.0       11
# 11.0       10
# 17.0        7
# 23.0        2
# 19.0        1
# Name: Newalc, dtype: int64

# %%
df['Newalc'].corr(df['PHYSHLTH']) 

df[['Newalc', 'MARITAL']].corr()
# Out:
#            Newalc   MARITAL
# Newalc   1.000000 -0.081481
# MARITAL -0.081481  1.000000

# %% [markdown]
# ## 9. Based on your initial data exploration, what are some hypotheses of what affects a person's health that you would like to further investigate?

# %% [markdown]
# Type out your initial hyptotheses below:
#
# 1.
#
# 2.
#
# 3.

# %% [markdown]
# ## Bonus: Create some cool graphics.
