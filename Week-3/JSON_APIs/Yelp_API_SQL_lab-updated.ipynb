# %% [markdown]
# # Yelp API - Lab
#
#
#
# ## Introduction
#
# Now that we've seen how the Yelp API works, it's time to put those API and SQL skills to work in order to do some basic business analysis! Taking things a step further, you'll also independently explore how to perform pagination in order to retrieve a full results set from the Yelp API!
#
# ## Objectives
#
# You will be able to:
# * Create a DB on AWS to store information from Yelp about businesses
# * Create HTTP requests to get data from Yelp API
# * Parse HTTP responses and insert the information into your DB
# * Perform pagination to retrieve troves of data!
# * Write SQL queries to answer questions about your data

# %% [markdown]
# ## Problem Introduction
#
# For this lab you will analyze the yelp data for a group of businesses to learn more about an industry. You will choose a type of business (Italian Restuarants, Nail Salons, Crossfit gyms) and a location to analyze. Then you will get data from the Yelp API, store that data in a SQL Database on AWS, and write queries to answer questions about the data.
#
#
# ### Process:
#
# 1. Read through the SQL questions and the API documentation to determine which pieces of information you need to pull from the Yelp API.
#
# 2. Create a DB schema with 2 tables. One for the businesses and one for the reviews.
#
# 3. Create code to:
#   - Perform a search of businesses using pagination
#   - Parse the API response for specific data points
#   - Insert the data into your AWS DB
#
# 4. Use the functions above in a loop that will paginate over the results to retrieve all of the results.
#
# 5. Create functions to:
#   - Retrieve the reviews data of one business
#   - Parse the reviews response for specific review data
#   - Insert the review data into the DB
#
# 6. Using SQL, query all of the business IDs. Using the 3 Python functions you've created, run your business IDs through a loop to get the reviews for each business and insert them into your DB.
#
# 7. Write SQL queries to answer the following questions about your data.
#
#
# Bonus Steps:
# - Place your helper functions in a package so that your final notebook only has the major steps listed.
# - Rewrite your business search functions to be able take an argument for the type of business you are searching for.
# - Add another group of businesses to your database.

# %% [markdown]
# REVIEW
#  total
#  reviews
#  reviews[x].rating
#  reviews[x].time_created
#
# ## SQL Questions:
#
# - Which are the 5 most reviewed businesses? - REVIEWS
# - What is the highest rating recieved in your data set and how many businesses have that rating? - RATINGS
# - What percentage of businesses have a rating greater than or  4.5?
# - What percentage of businesses have a rating less than 3?
# - What is the average rating of restaurants that have a price label of one dollar sign? Two dollar signs? Three dollar signs? P
# PRICE $$$
# - Return the text of the reviews for the most reviewed restaurant.
# - Find the highest rated business and return text of the most recent review. If multiple business have the same rating, select the restaurant with the most reviews.
# - Find the lowest rated business and return text of the most recent review.  If multiple business have the same rating, select the restaurant with the least reviews.

# %%
#COMMIT WHEN INSERTING DATA

# %% [markdown]
# ## Part I - Set up the DB
#
# Start by reading SQL questions above to get an understanding of the data you will need. Then, read the documentation of Yelp API to understand what data you will receive in the response.
#
#
# Now that you are familiar with the data, create your SQL queries to create the DB and the appropriate tables.

# %%
import mysql.connector

# %%
import config
db_name = 'Plumbs'

# %%
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    passwd = config.password,
    database = db_name

)
print(cnx)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x10f7ae748>

# %%
cursor = cnx.cursor()

# %%
from mysql.connector import errorcode

# %%
def create_database(cursor, database):
    try:
        cursor.execute(
            "CREATE DATABASE {} DEFAULT CHARACTER SET 'utf8'".format(database))
    except mysql.connector.Error as err:
        print("Failed creating database: {}".format(err))
        exit(1)

try:
    cursor.execute("USE {}".format(db_name))
except mysql.connector.Error as err:
    print("Database {} does not exists.".format(db_name))
    if err.errno == errorcode.ER_BAD_DB_ERROR:
        create_database(cursor, db_name)
        print("Database {} created successfully.".format(db_name))
        cnx.database = db_name
    else:
        print(err)
        exit(1)

# %%
# cursor.execute('DROP TABLE Plumb_biz;')

# %%
db_name = 'Plumbs'

TABLES = {}
TABLES["Plumb_biz"] = (
   "CREATE TABLE Plumb_biz ("
   "  biz_id varchar(100) NOT NULL PRIMARY KEY,"
   "  biz_name varchar(100) NOT NULL,"
   "  review_count int(16) NOT NULL,"
   "  rating int(7) NOT NULL"
   ") ENGINE=InnoDB")

TABLES['Plumb_Reviews'] = (
    "CREATE TABLE Plumb_Reviews ("
    "  rev_id int(71) NOT NULL,"
    "  rev_rating int(8) NOT NULL,"
    "  name varchar(40) NOT NULL,"
    "  user_id varchar(40) NOT NULL,"
    "  review_text varchar(5000) NOT NULL,"
    "  rev_date date NOT NULL,"
    "  biz_id int(40) NOT NULL,"
    "  PRIMARY KEY (rev_id)"
    ") ENGINE=InnoDB")

# %%
for table_name in TABLES:
    table_description = TABLES[table_name]
    try:
        print("Creating table {}: ".format(table_name), end='')
        cursor.execute(table_description)
    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_TABLE_EXISTS_ERROR:
            print("already exists.")
        else:
            print(err.msg)
    else:
        print("OK")

# cursor.close()
# cnx.close()
# Out:
# Creating table Plumb_biz: already exists.
# Creating table Plumb_Reviews: already exists.

# %%
url = 'https://api.yelp.com/v3/businesses/search'
client_id = "kSJKHzaATCEw4bxY9tJGwA"
api_key = "xZce1e9e3JthFVYS0eQm1Aa6thcOEaQ2N2hzi3PJsJrv6ga4hinQMYsPWTBYQYRikD7sN9H7HQJV9sDPBoIf-m2Ko-0rw5ouSZhGgUtQDYA5_5hEipYddHf7Ct2xXXYx"

# %%
import json
import requests
import time

# %%
term = 'Plumbers'
location = 'Bushwick NY'
url_params = {  'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit' : 50,
                'offset' : 50
             }

# %%
# url = https://api.yelp.com/v3/businesses/{id}/reviews
# headers = {'Authorization': 'Bearer {}'.format(api_key)}
# response = requests.get(url, headers=headers, params=url_params)

# %%
def yelp_call(url_params, api_key):
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {'Authorization': 'Bearer {}'.format(api_key)}
    response = requests.get(url, headers=headers, params=url_params)
    
    data = response.json()['businesses']
    return data

# %%
def parse_id_results(results):
        parsed_results = []
        plumb_list = []
        for result in results:
            yelp_dict = {}
            yelp_dict["biz_id"] = result['id']
            parsed_results.append(yelp_dict)
        
        for plumb in parsed_results:
            plumb_tuple = (plumb['biz_id'])
            plumb_list.append(plumb_tuple)
        return plumb_list

# %%
num = response.json()['total']
print('{} total matches found.'.format(num))
cur = 0
while cur < num and cur < 1000:
    url_params['offset'] = cur
    results = yelp_call(url_params, api_key)
    parsed_id_results = parse_id_results(results)
    cur = 50 + cur
    time.sleep(1) #Wait a second
# Out:
# 50 total matches found.

# %%
cursor.execute('''SELECT biz_id FROM Plumb_biz;''')
biz_ids = cursor.fetchall()

# %%
biz_ids
# Out:
# [('-CsL219aKfHi7iPw0YSVEQ',),
#  ('-GqZkEMSA2O-7wc6nEiG4w',),
#  ('-YtGo9TQjaEV7K3gPFmQuQ',),
#  ('00wogt3EfiEJW2T0weSr1w',),
#  ('0JES2rLBuWvsfQ249PpWbg',),
#  ('0m1dRGzPNlx_JLKo6lRaTQ',),
#  ('1Bq3rwwe7vPEZvUA3Q9PUw',),
#  ('1Eic2ZXa4BUYZfJb65WO7g',),
#  ('1M5qDSvsfNogoZeXYx2icg',),
#  ('1pnxGWn5aOTV2LKjC91DAw',),
#  ('1Sefmcnb_FdvQrsALgFEcQ',),
#  ('2n1uXZtrN2vIY9iKku6zTw',),
#  ('2rMHF-tMnF_I_PCN0MM-UQ',),
#  ('2U-ekZMq7IFin7JvY-RSNQ',),
#  ('2_j3xkRZXsI1_WIVJsacsg',),
#  ('3020UCNczgSJLYD1-JrDMw',),
#  ('37gZ1A8V-WwghnSawpEi1w',),
#  ('3ecwPT6aKE1sV1F4kydJsw',),
#  ('3JJdXZaaI0JOZ0kUWzAEBw',),
#  ('3NfHSucKngDvz24lRnDNjA',),
#  ('4-BL7dutEIm8WQNvsvPqdw',),
#  ('45hg5t6uHHzVNVxx4h9Cnw',),
#  ('47eRRdi0QEeHlP0BGZKtNQ',),
#  ('4K7AoV3ERYL7T2allzERnA',),
#  ('4oiVR8uY1VtUA06PJ5bA_Q',),
#  ('4QLDHUwDRlPlfjW_KTbyDQ',),
#  ('4uCT_ZMzv7jUojQgt1qzkw',),
#  ('4VZoPBVtKRqt7bowq5iNzA',),
#  ('4Zz720ccHd7_scM_dEFH8w',),
#  ('51AwoyBg4y5pqwAw1RsUyg',),
#  ('5fvwivv1vcZNOYWpgURiRg',),
#  ('5T6_inkams7H4hSoWqny9w',),
#  ('5UxKiYOwkjp5H2RsYVTF_g',),
#  ('5VFuLOWRFnFoNzKLGDhjpQ',),
#  ('5wVXlHH3YWcR_f5BRZ9-Eg',),
#  ('69qO49OFeqWw8JppS2buBw',),
#  ('6A7E0xAeA834uttwKl_UMA',),
#  ('6CDlmLCFjVIFNvhp4Thm2A',),
#  ('6H085VCLAzvcwuRAj4hEew',),
#  ('6hYb3yQFNNzQOtL8hTVayQ',),
#  ('6mwPCQbxKVe-4AQbvZwKkA',),
#  ('6RxIQmP7-o8AOjB98-lJXA',),
#  ('77Y0T0c2iSYFm7gulBx36g',),
#  ('7C36QCNOMOAejQNbD1BmYg',),
#  ('7fAwtd_gagCXXd9bKJcsow',),
#  ('7HMPXOMFTa5FSsGyc5LXkw',),
#  ('7IsAs2pTto-naK8puUqn1A',),
#  ('7JJdMi8XOxxVqzar7_sk4g',),
#  ('7kiPvp9bncNOx8IpbkZHPg',),
#  ('88m-OrPXtW8HP14Qtk6h7w',),
#  ('8bbyCzR7UdSkNSzRzWfVMA',),
#  ('8dlb1fT89EQdZwv7qC9hvg',),
#  ('8E1bDQzKertDZ1r_yvUq9g',),
#  ('8ek4xcanE4sykumKuYcbuw',),
#  ('8gnARxjY7Wij46PIPgJ92Q',),
#  ('8iA0yj8qMyup0yKnJD282A',),
#  ('8merK605xAIJQXTEnH_1iQ',),
#  ('8sqtpndjbVSw3Stg508dIg',),
#  ('8xbhkQdF8SKdsbFvWnJfWA',),
#  ('9atlYIexs7czA8XXvKVWhA',),
#  ('9KHx3LSwQEW1BDiKt5iybA',),
#  ('9WdVa4q9815NC5kPtrt36w',),
#  ('a1cra0MhOEYt8yqOMRSJMA',),
#  ('A3klelSteMN2vXo03kNtnQ',),
#  ('a6TKGWUFop1T-nlEIi8aNA',),
#  ('A8wnay9XuCcj1g0RoaTrew',),
#  ('AAvCMSNlKugRV_EJNfGORQ',),
#  ('ACo6MbcsfJCy3CAmzPwr9A',),
#  ('aD4iVmjokKSK8HDm-L-dlQ',),
#  ('aHBbc3yWNo6D6pQ015_DUQ',),
#  ('AmzUR0OI251i3UKGkKW2MA',),
#  ('AnWK1Yk2cZJl7MT3jeTJgQ',),
#  ('aoiapm41TVWtxGWVfn-jbg',),
#  ('AQIF7JjZuflqOot2l4LGgg',),
#  ('AqpRoRQp3YKght_yIuv0QA',),
#  ('ASHOZhNTDJ8Xtt8SRyCv1g',),
#  ('AvQ7-YEFFkb_93LJWxn8PQ',),
#  ('B-2LSu_gihds8uQbeQJ2DA',),
#  ('b4efA2_fP7KsPWhu5n4rRQ',),
#  ('BAZtO3_iRya1L-4x0sMxlg',),
#  ('beonpCBKiFvh_VCDytclng',),
#  ('BF1e6ud2EWwENkyyNnh7FQ',),
#  ('BG0J_jeAy65klDrtMAiX2A',),
#  ('bhcw9zq-e1qz-Q3gMLIx0Q',),
#  ('BJynQ-BsBNbBWK24Z9S8PQ',),
#  ('blegTLy0zPWqG43vcJXMQw',),
#  ('BlVq-v2ZLBfCgPI902nCqw',),
#  ('bmW3FjG_Hyxgy9iGEitKMg',),
#  ('BuvydZ9elHm5hH15skukyg',),
#  ('BXumg8WINlWIB5XvDHNIKw',),
#  ('ByNIdGHCJrpIQ_WmtRTXoQ',),
#  ('Bzc6ZixjTfNBnPA2BkiBRQ',),
#  ('BZGpJ9HqXUbf21MEA5P5Bg',),
#  ('c-JHV3pfYhf-nLncbnsBhQ',),
#  ('C23_gK48Z6DQ7kHFVBHsCQ',),
#  ('c3XHL91Rod1oLxtoBqKn_Q',),
#  ('CDtoqJBNIrrIE6_-wnaPrg',),
#  ('cEBX7dMfij3p_OjZxLdZiw',),
#  ('ClQO-DvsfOb6ht1N0vV7-g',),
#  ('cM8g5kwf-y287YvqamrEJw',),
#  ('CrMVq-KCxeo3DyJOUNAUMg',),
#  ('cSGov6ghxDg94jEXfq0U_Q',),
#  ('cvmgq9IWizNkGcm9eHbyIA',),
#  ('CwBjwKBnIQiJYYaCBEcXIA',),
#  ('CyxdTL80vjrMVqmTteFRuQ',),
#  ('D-Icj_K7JfUsNsY4MPqFmQ',),
#  ('d5c6loQ3RxkAt7OAmrd7fw',),
#  ('d5ow7expzUIXaTiQNiN9EA',),
#  ('D7D7GITROySJ254Oqjf7SA',),
#  ('D8jfrVqFgoz_opwzB7DhSA',),
#  ('D8oG3F6yeivarJxMS9LBmg',),
#  ('dEM5ZlLM02Ik4E7-ncdQCA',),
#  ('dNdqqq7xqTzEYSDybMyS-Q',),
#  ('DNHs2d7uzfORCOWD6WILXg',),
#  ('dONvd_M737rlxpYr6r7OfQ',),
#  ('dpG_aksEVIT0VxzHkepNIw',),
#  ('drIBxbybVcKXF0UmpkSg-A',),
#  ('DTM9ce1nGpAyeFPpSVtJFw',),
#  ('dy2HBt06bbbcbOrdLUndIQ',),
#  ('DzgjPAeTGA8ncokuErTGMw',),
#  ('d_FccVYYBPOdnBX-Mad-8A',),
#  ('e7kc_Dq2yLnZT3wVL5uGgg',),
#  ('E8mJonqk5boazttfq9UJWg',),
#  ('eBfc3wWB-WlH9AyYJX3_AQ',),
#  ('eDhhsdVwBLBBZRc0OVWEwA',),
#  ('egxgH55m32oG7onS26bP5w',),
#  ('EJMDb2FqR0H41jFtCZSoFg',),
#  ('EQT9NA2-n_1bYcOxWF6Vzw',),
#  ('ERdEPcRSpVzOmQ0GojxXwg',),
#  ('es4hmnEGOMyULeYfuTlZyg',),
#  ('EtKGVUVIzaBZykLo7JW4DQ',),
#  ('etO4qGkDyyl4N4F82hMwAQ',),
#  ('eu8I4n9NI-rzJZVAIAk4Ig',),
#  ('ex_eai9hXrlhNFC4KOMeqg',),
#  ('ez2MCxu-Kpn8FxlTq9vl0A',),
#  ('F0T-8LZn8_DiCs-L9x9S1w',),
#  ('F5JBQV5Ndv04o5k44EMPYQ',),
#  ('F7ichkrXQgDch-6hPbJv4w',),
#  ('f7sNPZrZ8XunVKaGqOJdRQ',),
#  ('F7xM9wjhx3VSiHlFHJ_2cw',),
#  ('FDSDIOVyU0T_pw43Ok2O7Q',),
#  ('FDW7qXwZBnyxLylXVgSpVA',),
#  ('FGm82IPkwdIWJlmO5VITeg',),
#  ('Fk2qzeAU343i9jDWM13qvA',),
#  ('Fm4EDeBj2Uwlebve3y0D0A',),
#  ('Fn0aowwtFAO4lFNEL-KURg',),
#  ('fre7S-ZmfqRCSFkeO0CwBA',),
#  ('FwY3aHeXzY-3wuETA-PJ6g',),
#  ('g0lVwQATOLgVcrEz6NAj8g',),
#  ('G4yKBnKAB1xfNerCCJXNuA',),
#  ('g5kfI33jirjUxeYPK6DU_w',),
#  ('g74Vl6ohK3YxnfILk6r9hA',),
#  ('gc6BhF9cWvkWdpzugfWNIQ',),
#  ('gDx__h_Fnx80d17_Vb947Q',),
#  ('ghnRqY_Fsua61VJaG6qXJQ',),
#  ('gJGYMWCuF6deQnt2f985HA',),
#  ('GkCcKoRxved6zImzs9_OEg',),
#  ('gNK2o-dVkxKqh-QtxxJ0JQ',),
#  ('gQH8Y6uPSctZUmXqisFLSw',),
#  ('gqPmu4v6q6bG2p4R8SXQKQ',),
#  ('h0OoIDNxhcNpR3lkIhAmbg',),
#  ('h5-purdTUJoukLQhihiTBQ',),
#  ('H6S0YxC80Uq93DhI67bcLw',),
#  ('h9UCAoIoYegROiuJnvhacQ',),
#  ('han8zgVwsxnd_fHrco8P9w',),
#  ('HAovQocy6YbMbV_IyiV39Q',),
#  ('hbgdlYcBILlA1XkwxW-TlA',),
#  ('hHXf21ck02orzA0L-VhxiA',),
#  ('hhya_WisfgXwxF24QfamfQ',),
#  ('HIJP7oYfKDf935usqgLemg',),
#  ('HJPIzhPYJgG1VgdN19CE0w',),
#  ('hlMkCkl-8wmFD57rD_JEJg',),
#  ('hQLBGB0ljn5l42jVr1oyUA',),
#  ('Hqng1ObbMPPET3hvrkmtdw',),
#  ('hRKPkt5zFzxoDgDnNxJO9g',),
#  ('hw0-T1gdS6gvVemVuOhR2Q',),
#  ('i-fjCqNziJwR5NfhQn0HDQ',),
#  ('i4EpaSIV7TPA-xt-WZdQFQ',),
#  ('iBICIumJC0fiVO_qraIqag',),
#  ('iEa5IsP5B--WRWDG6jMkgw',),
#  ('IidxRCySk_loNxS7_szt7Q',),
#  ('iigJdAs-JqOxxFcniQmWAg',),
#  ('ilX5ZFpPtNvcDqKYwbjP7g',),
#  ('im4w62jG3UWfKOmDvlv7lg',),
#  ('imRy45uQsH9A8pdINyQFDw',),
#  ('iOP5PMM3bzLlWVS00bkJZQ',),
#  ('ISeofmJ68_4ZC3oRUPBZlQ',),
#  ('izYheSimlA0esPTSHPIh9w',),
#  ('JasFa1H4E8cAR6GxSLS-kQ',),
#  ('jdcTXh20Lg6p1jaC2vix3Q',),
#  ('jiCmQpuCNgThIvL-_vQsag',),
#  ('jPDbRYDSAtdPQIKjxGms2g',),
#  ('jrCzozcPZEdjXnKEGeNcdA',),
#  ('JTrc5dT4H0ZiYj2d1WuI5Q',),
#  ('jtV2FXMnqYAS16Ogeg8V9Q',),
#  ('K7lWXayp2qAnSOdmHHc_PA',),
#  ('k7myfBLnLbvcYCEcLBGXfg',),
#  ('KDgXNozXKgpgLJO5zU9YTQ',),
#  ('khBY7mNZ-cTcC8Etui6dxg',),
#  ('khegjriAzSEEYOZOwYF4fg',),
#  ('kItS6ibdwugnuAHh5fUBPw',),
#  ('kmYS2mYI2eZFaOssToW6tQ',),
#  ('Koi1c9wTwzvjciRyBaPrjQ',),
#  ('KQB1nN0O0v5itL8FndfQFg',),
#  ('L2o08zskZNYYQ8pj44uMGg',),
#  ('lA0xjopEvkIavu71E8zEsw',),
#  ('lCwlqpNKiEFOzz_SzqPmew',),
#  ('LFhCOwVF3ckUVSDZU74HVg',),
#  ('lFuWIb0ilxJQvFS6LVD1Tw',),
#  ('lhClHZD-ivrRwi7g1vsvIA',),
#  ('LmHldxg36t3yCaHmm4MfAA',),
#  ('Lmv4akOnGnveUEFG4cVMIA',),
#  ('LnshTb2O2ZoXWBWWlR1w9g',),
#  ('lrK1bqSq_NJp8mK3sjFJUQ',),
#  ('lrQjH6jo0Mzd2JqG-lz9-Q',),
#  ('lttNgQEJfRqY-ulkRt0kWw',),
#  ('lWAETw0VFdd-9pitMTeUTA',),
#  ('Lzv_Cc6cxNIYKatzpyxAtA',),
#  ('l_zre9vWJrU3lbcpACmu6A',),
#  ('MBPJRfAY7wCwL8I2KcPljQ',),
#  ('mCwXNqHJ6p1D6U8YjlIOtw',),
#  ('mIJ96qFwWK-fu9m-NcuZug',),
#  ('Mj2IwiVY3A3tH3l7RuzZFg',),
#  ('MjrVQP7oOoJ3GqzOpo3ddg',),
#  ('MO2AxMYZ-coBAl7t0uiDLw',),
#  ('MQQ88J64Jub_XkpjKU1vbA',),
#  ('mu8VUNkgJv0IKNa12vPxaA',),
#  ('mVUXBVUD_gdJt709bROXBg',),
#  ('mWSFujd-Kz1E01bB1bYMCQ',),
#  ('MXywrRCj-cnpnnnaEBRlxQ',),
#  ('N-O4eYtINgkYNkVwaQDbuw',),
#  ('N5UutvvtiPWgAK53-8YekQ',),
#  ('n8HuwTl7W1EprkzORrKTUg',),
#  ('nARgHI6sL-Y36DzvKgYp_A',),
#  ('ncfzsala0tUrYHxVR5LoeA',),
#  ('ND9saPOoUtwGDaLnfOrNdw',),
#  ('NKN6DzIm3zEgOy4rtrJjKw',),
#  ('nkqOAjgHJOOtwKCagEdSMQ',),
#  ('NoulDZM3OUPR4Wd5ebJclA',),
#  ('NQBGvmCfYiKG0o-lH_d5sg',),
#  ('Nr6BuB6WVXeyZKi_E4iGjw',),
#  ('nshCt83YkUseutjNzidTNg',),
#  ('NsQl7n9e3_jQL4qRHwxXiQ',),
#  ('NZ3C99YBPyaUbu7iFaZ6kg',),
#  ('o0WJDT2-EXDUFNtmQ2wEqA',),
#  ('o1vo1evIIUppsuG9q51c8A',),
#  ('O4e5BQqq6eG6_yCqTM4KaA',),
#  ('Oa3ENO6Jw-d2HPjN_1Etpw',),
#  ('OClOKAcb5U0tbk6PbBRn8A',),
#  ('odRC52y2pmc2_t-XB23YEg',),
#  ('oFCIdIA_BPP8hom39c4raQ',),
#  ('oGsXD7Y1Sk4CTctjRwmBRg',),
#  ('OhZaSzKsVGDLkX5eXJI5zg',),
#  ('oPGC8W7oaDmazWwQgJUnFA',),
#  ('ORmtkQyDLfJhtVqAjeovCQ',),
#  ('p-SiwLzGLcXVog1H5czhAQ',),
#  ('p2Or6m6Vek8BDJojDDmPlg',),
#  ('p4f8SQpBDAUo2pl9TDnUeg',),
#  ('p7d54o1WaJnGLJiiXSESIg',),
#  ('PAiyKfypPig7tJ2vVvs0Og',),
#  ('pcnUHtFociwVQdL5a37HQQ',),
#  ('peOv04SsygJH2VD7vM-QJg',),
#  ('PF0upaxFu7Qzq2IUPFtQKw',),
#  ('pkp8eLJgzzSvGQJYRJKniA',),
#  ('plzr7QgqgySgPv6timtjOA',),
#  ('poBVDcy11av0DAmpRghr7Q',),
#  ('pOCuiGKW_lOHpzQjEH4N1w',),
#  ('PQRXZVEjkKAsAuG0Y6KdWA',),
#  ('pR1zhIPaO2BJF5I_6DREQw',),
#  ('PRxRkT6rJUzcyo9_5S5ErQ',),
#  ('pv3ULKYKWlOJKjTA4bF-hQ',),
#  ('PvuChiGcd-T-KIPRl7SVqg',),
#  ('PwD6T7__hQR_KSThDmpU7g',),
#  ('q5_gXLKK_Qs9NKI_dW3ypQ',),
#  ('qCRt7cSktpkfYZoFIy6vqA',),
#  ('qdoR9CFya2xJY2PGKMoAwQ',),
#  ('QepLWqWQ5kDaWDvr5tfcOg',),
#  ('Qetmd5UhckeZK-JZDEc3yw',),
#  ('QF9xq-M7KylekFE_ba7TmA',),
#  ('QP-kAGsq5ddz8JEBx2apQA',),
#  ('QPaEmBF6v0ljeG89oHg_NA',),
#  ('qQitcWbnRDVLJou8VGKPdw',),
#  ('qrJ3luOuATaO5Vu86Gk7YA',),
#  ('qU2itRJ1E7cZ6UsOZwWGcA',),
#  ('QWLV0ogATd40C-quLY3Okw',),
#  ('qxY8Gc1Tc0sq9dz-lH_7QQ',),
#  ('QYYRETgggysR4ENCA2iyEw',),
#  ('QzpYYXgFsz7aCLgm1goDaA',),
#  ('r-UxNIwsZH1KSnMkkHhZvQ',),
#  ('R5vfxUuI8FQI4Ptbgbu43g',),
#  ('rcwMtRpoc3VHAOXMsEkt-g',),
#  ('RD7oMjuoboADF1G03vpv-A',),
#  ('RdODOZiZIwIX2v9YAkgP0A',),
#  ('rfXkDq_3qzcLrR_Jvt9LyA',),
#  ('RgBMW-m8nAy4KWrkxgM4Kw',),
#  ('rha78tVP6CP9frWsGUIhGw',),
#  ('Rj6uRroFAzGU_KY7Q1czig',),
#  ('RjiE9c8x1SQkHcHGLhpmFQ',),
#  ('RkTZazVLIYgRYpPbGBm6Yw',),
#  ('rV5mwuyEpE6I9k_0kjo5xA',),
#  ('rWWzSl0CQpAHM9cx-eYOsQ',),
#  ('Rw_uluAIegnM3H8_i3v_bg',),
#  ('RxSSOUdaX5KWbG1jWd1Y3w',),
#  ('s0JGhggBUESy5gFXGgi9uQ',),
#  ('S3O340Dznk5I0mBG3tS0TA',),
#  ('s7154ePHZ9-yup5xc6mF2w',),
#  ('s82-pmfjpQv3W1MSG7hWFw',),
#  ('S9sGRfMNmXf1EYSu4iaB7A',),
#  ('sFvwtpQZ0O2Qha9ynnmQZw',),
#  ('SGFRYzRsp3dTxDiCAbi-Pw',),
#  ('SgSUHdo3KPLaFF2Vuwqn7Q',),
#  ('Sh-JN9TrIBbxLqpCief11Q',),
#  ('ShpZHV9PJR_HiiireqHGUA',),
#  ('SIOmy4poveQiZXTgZ9tFww',),
#  ('sj7o8xbpMpR_HsJAxr1Xgw',),
#  ('SMLmUtSAteRRG3lmLjr7-w',),
#  ('smwU-HtMB0YtNnr62l19Gg',),
#  ('SNDbL0QNmxH0-_aOyFYRvg',),
#  ('SRlDHuDReq4KxSm6R3Kk-g',),
#  ('sU4WRHmmjS9Jg89wsv662A',),
#  ('SuHjb6wXZpKg-wm4w7ogaA',),
#  ('suYpGz_jE6141cOzDz7qrw',),
#  ('sWAZ9F6qKh1YIe1kcHJ-Dg',),
#  ('sxLnKiQJfu9Yxr7GHFFQmA',),
#  ('SXty2WfaVNB5Z1OMNh6vxA',),
#  ('SZC6RYx7gwuYFQHi_UIjig',),
#  ('S_Oi5h4Ul9QTCP76yUO4xw',),
#  ('T4lIDkWFxNWW_x8m9Ho2qQ',),
#  ('t5s-f2Y8kc6cDZTY76uXgA',),
#  ('T721jY28j6k6mtiIONo5Hw',),
#  ('T7jqnxG0eo-cXpGg_HcESA',),
#  ('TagwXvJiKviTAs-7QbPjyw',),
#  ('Tan2JA6FEoa_5zSZaRprBw',),
#  ('TjStUcBU_cv7tRG4tNudzA',),
#  ('tK_4kHnCMoDuyHppjuBQQg',),
#  ('Tk_frH4P64ncUGyI3qGatQ',),
#  ('TlEBPJKvCD7J_Wwzamb1YA',),
#  ('Tmad_kC6JiIfLQpMbcwV1g',),
#  ('TnShifQc06Waajnhs396XA',),
#  ('tNYiixKuXb6FcL38g8MtBg',),
#  ('tO6mpds-ALxQzH-Udga3pw',),
#  ('tQnALMtXO80KoZpIcKTWRA',),
#  ('TUpR9ga0Joros4VFL4BWpA',),
#  ('tWwe9cuk985yQc9BL1g7DQ',),
#  ('tXtXY7r8NXPk0-MKJlrOjQ',),
#  ('TyAdfPE-LEH7rhtDjGCjyA',),
#  ('TYbq5VFqX32K04NhQj3gVw',),
#  ('TYdz9vpLiXFF7-kbwbx1cQ',),
#  ('TYGE2uNwJLJTw7xJRTkgyA',),
#  ('TyXqIrjNeW7NxbQCsFA16g',),
#  ('U4eItfkb9Mfa_vDa6d76Mg',),
#  ('U5alU6jaBOTVIwpfIyVLjQ',),
#  ('uEolFnGjUzE3ZXXEfsYfcA',),
#  ('UflrfV0xeP1hqgP3Jyqs9w',),
#  ('UfQ_K7pZZ9asStT4y8z24A',),
#  ('ugo-TEEdIQwC1igj3im0xw',),
#  ('UHVnG6pUuoHEyQfclK6QlQ',),
#  ('uKeLC7up9k3m2adsSsZVhw',),
#  ('ULwvCqGF0lmUl0ZmMl_Qmw',),
#  ('unhAxJO8uFdN064dEDRnnQ',),
#  ('uq5TUW8cKUC9rxGBR3WkHA',),
#  ('UsJVY50F1CE-Ia4evLCghw',),
#  ('USsujTfyIHZ7Bf8jwCiz5g',),
#  ('Uwz_EoShy10k1AktBjx_Bw',),
#  ('ux-b_AJkRZ7cKUI5GouAxA',),
#  ('v0BFp6BDPIdzNPTc2X0TCQ',),
#  ('V2V4hdXqQC2oJ0BFXdfV3Q',),
#  ('V9f8sDNed-euUjhKX8Wh0w',),
#  ('vdrxkVeTuXbY8_hMcA7dMA',),
#  ('Vg7mRYSPF5NbhNIy59Vkpw',),
#  ('VHhpuWMw_e3S9fv6uag05w',),
#  ('Vq105fjgucPhAzVdjq1nSw',),
#  ('VQk9zaPs3YWKPwKkZz6gDw',),
#  ('vvstMLY0ZaMnaYbh_KyJ5w',),
#  ('vW9Y0CqqlZp6qzHprRe_HA',),
#  ('Vxk5YwTGzVTuSj4Mtk_s6w',),
#  ('v_4ZoF_4ruSAkOqVrtC3Cw',),
#  ('W2y0Kpj7WS13ZAi_u8e2Ng',),
#  ('WbycvD-bUHheEPCrGjE9Bg',),
#  ('WdbSa8U-mvBrwFmyKriOoA',),
#  ('wEM165XZfDEkjclhLiD-yg',),
#  ('wf2TOz4q8H-vRJySu213kQ',),
#  ('wHtueiaLn54AUbKrF_bh-w',),
#  ('wKwesOtja1EeK1Jshy6UNw',),
#  ('wlZmsA0yWsOHquZh7dcOEw',),
#  ('Wnom5MGEi0W4FgCvTjtflw',),
#  ('wO56AdkEr7cxMDeZUQ7AGQ',),
#  ('wp4-pXAp16-NzKXdF2q4Kw',),
#  ('WpdQgiCxPBUHNjX71QT-JQ',),
#  ('wRBy5CRKa5dGOwhTN6cUAQ',),
#  ('Wrw8gbjbUmewVlCQ3zV24w',),
#  ('WshmZO5_yE593O9id-BLmQ',),
#  ('wUfJhp7IL9MlGID93vCHkA',),
#  ('WVhUiCyjymE14EGO39Jl7Q',),
#  ('WYg0nsSNM_N_gB2H8OKTdg',),
#  ('wYPHMySAe6e_qAmrix_9eA',),
#  ('xi3QfmE5pHOt4UueMdqVow',),
#  ('XjIl_1B4ONytdJfnn1IoQA',),
#  ('XNkDvp97M6TeBy4A1SoRLg',),
#  ('xnxilNvo_8ctLwX1CHvIyw',),
#  ('XYcSeWuYZADvq3QeLcT4Ew',),
#  ('XYsyUwdwqizUzEWdbEQcqA',),
#  ('y8QoE4J4Lw5q-PHqCziikg',),
#  ('y9pQ0xi6HOgGgaF6jL7n-A',),
#  ('YBhJPxvWXAeWnmxhzctQPg',),
#  ('YDtNhbwN5OCrx6kF98Y1NA',),
#  ('YGYTvJXmvIaQcENKbMiXIA',),
#  ('YhMOFssCDCDXbe4o-fuUlw',),
#  ('yIIZPbtGLhGkNEVSwMrFrw',),
#  ('YlEq67iLximfx9Mwjfbnqg',),
#  ('ypFZ3-hyZGgjQNf7IPeYZA',),
#  ('Yr6mLnzq5UQbNbhcDDlEBQ',),
#  ('yrg6PhWvmL6qIeDXZIEt3w',),
#  ('Yt-kjA8qIyXuoOoIKgd7PQ',),
#  ('YYY90NgG271Lh9aQm4SynQ',),
#  ('zfJ87FrjrRq1MDYORvkRFg',),
#  ('zg267A7rvb27cXyY2pH0jA',),
#  ('Zg6mP9nhSasqFDsARdXzKw',),
#  ('ZHf8BgfSVp28SiqPurrr8A',),
#  ('ZkGRxu8AMBZ4ZBx5GRJ5HQ',),
#  ('ZnMyiLNJqInJbQ1n-zpSSA',),
#  ('zO1ODFYMX-nbOMVDam5tjg',),
#  ('zp4qPlbQOkfnEjXCO323lg',),
#  ('ZPYr-_hXbvgnQocOy3X_Ig',),
#  ('ZtV7yqIHh5Cv-jTkPgpbsw',),
#  ('zw0wcPj8LsuCzhPj8WD7LQ',),
#  ('ZxmYRN3HplFZ3Htc91uNiw',),
#  ('ZxujtZ7vy09FGrzRkHHDAg',),
#  ('zz_Joj1-cM0Ly_3PggAnEw',),
#  ('_7do3iUkk1S_T9T6smJQVA',),
#  ('_ArAJkj1ofOVqjrG23SmXw',),
#  ('_Ea65-QNENYZlgIb0yyMeQ',),
#  ('_KKSg4fecByxPclVahloDA',),
#  ('_KnZZ7t87IsjPv-p6C98Gg',),
#  ('_kuI5rqM6da2JR-XnuCtgg',),
#  ('_p-CaP2hfWjlx9O9kmLyZg',),
#  ('_PBxT0d99zQTdaaaMiAKbw',)]

# %%
def parse_results(results):
        parsed_results = []
        plumb_list = []
        for result in results:
            yelp_dict = {}
            yelp_dict["biz_id"] = result['id']
            yelp_dict["biz_name"] = result['name']
            yelp_dict["rating"] = result['rating']
            yelp_dict["review_count"] = result['review_count']
            parsed_results.append(yelp_dict)
        
        for plumb in parsed_results:
            plumb_tuple = (plumb['biz_id'], plumb['biz_name'], 
                     plumb['rating'], plumb['review_count'])
            plumb_list.append(plumb_tuple)
        return plumb_list

# %%
# def parse_results_reviews(parsed_results)
        
#     for result in parsed_results:

# %%
def db_insert(data):
        insert_statement = "INSERT INTO Plumb_biz (biz_id, biz_name, rating, review_count) VALUES (%s, %s, %s, %s)"
        cursor.executemany(insert_statement, data)
        cnx.commit()

# %%
x = yelp_call(url_params, api_key)
parse_results(x)
# Out:
# [('tXtXY7r8NXPk0-MKJlrOjQ', 'Friedman Irwin & Son', 4.5, 50),
#  ('1M5qDSvsfNogoZeXYx2icg', 'Pipe Monkeys Sewer and Drain', 5.0, 28),
#  ('hlMkCkl-8wmFD57rD_JEJg', 'Dov Sewer and Drain', 4.5, 56),
#  ('a6TKGWUFop1T-nlEIi8aNA', "Sam's Plumbing Services", 4.5, 19),
#  ('g5kfI33jirjUxeYPK6DU_w', 'Michael Donahue Plumbing & Heating', 5.0, 25),
#  ('TYdz9vpLiXFF7-kbwbx1cQ', 'Parkset Plumbing', 4.5, 20),
#  ('4PJwxWz0V6lcLjPJ-97H0A',
#   'Alexanders Proficient Heating & Cooling',
#   4.0,
#   38),
#  ('3020UCNczgSJLYD1-JrDMw', 'Four Season Piping & Mechanical', 4.5, 24),
#  ('QzpYYXgFsz7aCLgm1goDaA', 'The Original 718 Sewer & Drain', 4.5, 172),
#  ('ZnMyiLNJqInJbQ1n-zpSSA', 'JPeral Piping & Heating Sewer Service', 4.5, 45),
#  ('r-UxNIwsZH1KSnMkkHhZvQ', 'Franco Belli Plumbing & Heating & Sons', 4.5, 32),
#  ('dNdqqq7xqTzEYSDybMyS-Q', 'JCA Mechanical', 4.5, 126),
#  ('han8zgVwsxnd_fHrco8P9w', 'Vuksani Plumbing & Heating', 5.0, 5),
#  ('p4f8SQpBDAUo2pl9TDnUeg', 'The Clogfather Sewer & Drain', 5.0, 3),
#  ('DzgjPAeTGA8ncokuErTGMw', '123 Backflow Testing', 5.0, 2),
#  ('BlVq-v2ZLBfCgPI902nCqw',
#   'Taylor Group Plumbing, Heating, Mechanical & Sprinkler',
#   5.0,
#   1),
#  ('U4eItfkb9Mfa_vDa6d76Mg', 'The Pump Guys', 5.0, 1),
#  ('R5vfxUuI8FQI4Ptbgbu43g', 'Empire Handyman', 5.0, 13),
#  ('BF1e6ud2EWwENkyyNnh7FQ', 'ASAP Solutions', 4.5, 69),
#  ('VHhpuWMw_e3S9fv6uag05w', 'Empire Water Main & Sewer', 5.0, 10),
#  ('zp4qPlbQOkfnEjXCO323lg', 'Zabivay', 5.0, 60),
#  ('MXywrRCj-cnpnnnaEBRlxQ', 'Star Cities Plumbing & Heating', 4.5, 29),
#  ('CwBjwKBnIQiJYYaCBEcXIA', 'Safeway Sewer & Drain Cleaning', 5.0, 2),
#  ('8E1bDQzKertDZ1r_yvUq9g', 'A Real Good Plumber', 3.0, 13),
#  ('IidxRCySk_loNxS7_szt7Q', 'Northside Sewer and  Drain', 5.0, 2),
#  ('AqpRoRQp3YKght_yIuv0QA', 'SOS Plumbing & HVAC', 5.0, 1),
#  ('PF0upaxFu7Qzq2IUPFtQKw', 'OC Piping Service', 5.0, 12),
#  ('zg267A7rvb27cXyY2pH0jA', 'Kew Forest Plumbing & Heating', 3.5, 27),
#  ('FGm82IPkwdIWJlmO5VITeg', 'Joseph L Balkan Inc', 4.0, 45),
#  ('bhcw9zq-e1qz-Q3gMLIx0Q', 'Bk Piping And Heating', 4.5, 9),
#  ('NKN6DzIm3zEgOy4rtrJjKw', 'Federico Plumbing', 5.0, 10),
#  ('2rMHF-tMnF_I_PCN0MM-UQ', 'One Planet Construction', 4.0, 1),
#  ('LnshTb2O2ZoXWBWWlR1w9g', '1 Stop Plumbing & Handyman Svcs', 3.5, 3),
#  ('0m1dRGzPNlx_JLKo6lRaTQ', 'Hub Plumbing & Mechanical', 4.5, 120),
#  ('SGFRYzRsp3dTxDiCAbi-Pw', 'J V MECH', 4.5, 44),
#  ('YGYTvJXmvIaQcENKbMiXIA', 'Marcel Mechanic Plumbing', 4.5, 9),
#  ('WVhUiCyjymE14EGO39Jl7Q', 'CPH Services Corporation', 4.0, 3),
#  ('Tan2JA6FEoa_5zSZaRprBw', 'A1 Construction', 4.5, 41),
#  ('TnShifQc06Waajnhs396XA', 'CN Coterie', 4.5, 15),
#  ('EtKGVUVIzaBZykLo7JW4DQ', 'Tim Golden Hands', 5.0, 4),
#  ('zO1ODFYMX-nbOMVDam5tjg', 'Aurora Plumbing & Heating Contractors', 3.5, 7),
#  ('VQk9zaPs3YWKPwKkZz6gDw', 'Mario Construction', 5.0, 1),
#  ('dy2HBt06bbbcbOrdLUndIQ', 'Stitch Coterie', 4.5, 25),
#  ('eu8I4n9NI-rzJZVAIAk4Ig', 'Nationwide Plumbers', 4.5, 12),
#  ('XjIl_1B4ONytdJfnn1IoQA', 'Agalliu Contracting', 4.5, 11),
#  ('h0OoIDNxhcNpR3lkIhAmbg', 'Big Benz Plumbing & Heating', 3.0, 2),
#  ('nshCt83YkUseutjNzidTNg', '39.99 sewer service', 2.0, 7),
#  ('Fn0aowwtFAO4lFNEL-KURg', 'Meyerowitz Supply', 5.0, 5),
#  ('RgBMW-m8nAy4KWrkxgM4Kw', 'Petri Plumbing & Heating', 3.0, 91),
#  ('ugo-TEEdIQwC1igj3im0xw', 'Mr. Plumber', 4.5, 6)]

# %%
num = response.json()['total']
print('{} total matches found.'.format(num))
cur = 0
    
while cur < num and cur < 1000:
    url_params['offset'] = cur
    results = yelp_call(url_params, api_key)
    parsed_results = parse_results(results)
    db_insert(parsed_results)
    time.sleep(1) #Wait a second
    cur = 50 + cur
# Out:
# 437 total matches found.

# %%
results1 = yelp_call(url_params, api_key)
tuple_biz_results = parse_results(results1)
#get a list of the biz ids 
# def parse_results_reviews():
#       yelp_reviews = []
#           for result in prev_results_from_before:
#             yelp_dict = {}
#             id = result["biz_id"]
#             data = yelp_call_reviews(api_key,Url_thing,id)
#             yelp_dict["id"] = data["id"]
#             yelp_dict["reviews"] = data["reviews"]
#             yelp_reviews.append(yelp_dict)
#             time.sleep(.5sec)

# %% [markdown]
# ## Part 2: Create ETL pipeline for the business data from the API

# %%
locale = 'en_US'
url_params = {  'term': locale.replace(' ', '+')
             }

# %%
url = 'https://api.yelp.com/v3/businesses/{id}/reviews'
client_id = "kSJKHzaATCEw4bxY9tJGwA"
api_key = "xZce1e9e3JthFVYS0eQm1Aa6thcOEaQ2N2hzi3PJsJrv6ga4hinQMYsPWTBYQYRikD7sN9H7HQJV9sDPBoIf-m2Ko-0rw5ouSZhGgUtQDYA5_5hEipYddHf7Ct2xXXYx"

# %%
url = https://api.yelp.com/v3/businesses/{id}/reviews
headers = {'Authorization': 'Bearer {}'.format(api_key)}
response = requests.get(url, headers=headers, params=url_params)

# %%
def yelp_call_reviews(url_params, api_key):
    url = ('https://api.yelp.com/v3/businesses/{}/reviews'.format(biz_id))
    headers = {'Authorization': 'Bearer {}'.format(api_key)}
    response = requests.get(url, headers=headers, params=url_params)
    
    data = response.json()['reviews']
    return data

# %%
    
#get a list of the biz ids 
# def parse_results_reviews(prev_results_from_before):
#   yelp_reviews = []
#   for result in prev_results_from_before:
#     yelp_dict = {}
#     id = result["biz_id"]
#     data = yelp_call_reviews(api_key,Url_thing,id)
#     yelp_dict["id"] = data["id"]
#     yelp_dict["reviews"] = data["reviews"]
#     yelp_reviews.append(yelp_dict)
#     time.sleep(.5sec)
        
    "  rev_id int(71) NOT NULL,"
    "  rev_rating int(8) NOT NULL,"
    "  name varchar(40) NOT NULL,"
    "  user_id varchar(40) NOT NULL,"
    "  review_text varchar(5000) NOT NULL,"
    "  rev_date date NOT NULL,"
    "  biz_id int(40) NOT NULL,"
    "  PRIMARY KEY (rev_id)"

# %%
def parse_results_for_id(results):
        parsed_results = []
        plumb_list = []
        for result in results:
            yelp_dict = {}
            yelp_dict["biz_id"] = result['id']
            yelp_dict["biz_name"] = result['name']
            yelp_dict["rating"] = result['rating']
            yelp_dict["review_count"] = result['review_count']
            parsed_results.append(yelp_dict)
        
        for plumb in parsed_results:
            plumb_tuple = (plumb['biz_id'], plumb['biz_name'], 
                     plumb['rating'], plumb['review_count'])
            plumb_list.append(plumb_tuple)
        return plumb_list

# %%
num = response.json()['total']
print('{} total matches found.'.format(num))
cur = 0
    
while cur < num and cur < 1000:
    biz_id = [] 
    results = yelp_call(url_params, api_key)
    parsed_results = parse_results(results)
    time.sleep(1) #Wait a second
    cur = 50 + cur

# %%
def parse_id_results(results):
        parsed_results = []
        plumb_list = []
        for result in results:
            yelp_dict = {}
            yelp_dict["biz_id"] = result['id']
            parsed_results.append(yelp_dict)
        
        for plumb in parsed_results:
            plumb_tuple = (plumb['biz_id'])
            plumb_list.append(plumb_tuple)
        return plumb_list

# %%
list_of_ids = parse_id_results(results1)

# %%
url = ('https://api.yelp.com/v3/businesses/%s/reviews'% list_of_ids[0])
headers = {'Authorization': 'Bearer {}'.format(api_key)}
response = requests.get(url, headers=headers, params=url_params)
response
# Out:
# <Response [200]>

# %%
response.json()["reviews"]
# Out:
# [{'id': 'Yd5Cxu9YIwHVQObrLmW1tA',
#   'url': 'https://www.yelp.com/biz/friedman-irwin-and-son-brooklyn?adjust_creative=kSJKHzaATCEw4bxY9tJGwA&hrid=Yd5Cxu9YIwHVQObrLmW1tA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=kSJKHzaATCEw4bxY9tJGwA',
#   'text': 'Brandon did a superb job! Called him in to fix a shower and had a problem with my bathroom faucet during the time we were waiting on the shower part. Not...',
#   'rating': 5,
#   'time_created': '2019-06-21 13:59:41',
#   'user': {'id': 'V8ftzOvcy9eO8lePGqBJBQ',
#    'profile_url': 'https://www.yelp.com/user_details?userid=V8ftzOvcy9eO8lePGqBJBQ',
#    'image_url': None,
#    'name': 'Jeff B.'}},
#  {'id': 'HYqczo-J1uG5WA3TabF54w',
#   'url': 'https://www.yelp.com/biz/friedman-irwin-and-son-brooklyn?adjust_creative=kSJKHzaATCEw4bxY9tJGwA&hrid=HYqczo-J1uG5WA3TabF54w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=kSJKHzaATCEw4bxY9tJGwA',
#   'text': 'Super accommodating, onsite in a few hours and SUPERB JOB!\n\nThis is a fantastic group of plumbers and a wonderful group to work with. Superior work and...',
#   'rating': 5,
#   'time_created': '2019-01-03 11:44:18',
#   'user': {'id': 'U5wdxB4LLPpHHUGyqb1XxA',
#    'profile_url': 'https://www.yelp.com/user_details?userid=U5wdxB4LLPpHHUGyqb1XxA',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/SAMqeX_hQtfbMEnwzZxuAg/o.jpg',
#    'name': 'Jason D.'}},
#  {'id': 'P24bAMjBJTuf-rSgtMYCPA',
#   'url': 'https://www.yelp.com/biz/friedman-irwin-and-son-brooklyn?adjust_creative=kSJKHzaATCEw4bxY9tJGwA&hrid=P24bAMjBJTuf-rSgtMYCPA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=kSJKHzaATCEw4bxY9tJGwA',
#   'text': "I've contacted these guys twice and they could have been more professional in both circumstances.  First, was a broken shower handle and when they arrived...",
#   'rating': 2,
#   'time_created': '2018-09-11 09:07:26',
#   'user': {'id': 'pUKuBUfbZLz2ZOaGA4rhMw',
#    'profile_url': 'https://www.yelp.com/user_details?userid=pUKuBUfbZLz2ZOaGA4rhMw',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/pvT-3148y-_tCK-QqU6uew/o.jpg',
#    'name': 'Geoffrey H.'}}]

# %%
headers = {'Authorization': 'Bearer {}'.format(api_key)}
response = requests.get(url, headers=headers, params=url_params)
url = 'https://api.yelp.com/v3/businesses/search'
client_id = "kSJKHzaATCEw4bxY9tJGwA"
api_key = "xZce1e9e3JthFVYS0eQm1Aa6thcOEaQ2N2hzi3PJsJrv6ga4hinQMYsPWTBYQYRikD7sN9H7HQJV9sDPBoIf-m2Ko-0rw5ouSZhGgUtQDYA5_5hEipYddHf7Ct2xXXYx"

term = 'Plumbers'
location = 'Bushwick NY'
url_params = {  'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit' : 50,
                'offset' : 0
             }

import json
import requests
import time

def yelp_call(url_params, api_key):
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {'Authorization': 'Bearer {}'.format(api_key)}
    response = requests.get(url, headers=headers, params=url_params)
    data = response.json()['businesses']
    return data

# def parse_id_results(results):
#         parsed_results = []
#         plumb_list = []
#         for result in results:
#             yelp_dict = {}
#             yelp_dict["biz_id"] = result['id']
#             parsed_results.append(yelp_dict)
        
#         for plumb in parsed_results:
#             plumb_tuple = (plumb['biz_id'])
#             plumb_list.append(plumb_tuple)
#         return plumb_list
    

def yelp_call_review(api_key, list_of_ids):
    reviews = []
    for i in list_of_ids:
        url = ('https://api.yelp.com/v3/businesses/%s/reviews'% i)
        headers = {'Authorization': 'Bearer {}'.format(api_key)}
        response = requests.get(url, headers=headers, params=url_params)
        data = response.json()['reviews']
        data["biz_id"] = i
        reviews.extend(data)
    return data


def parse_results_reviews(previous_results):
    yelp_reviews = []
    for result in previous_results:
        yelp_dict = {}
        the_id = result['biz_id']
        data = yelp_call_review(api_key,the_id)
        yelp_reviews.append(data)
        time.sleep(5)


def parse_review_results(results):
        parsed_results = []
        rev_list = []
        for result in results:
            yelp_dict = {}
            yelp_dict["rev_id"] = result['id']
            yelp_dict["rev_rating"] = result['rating']
            yelp_dict["name"] = result['user']
            yelp_dict["review_text"] = result['text']
            yelp_dict["rev_date"] = result['time_created']
            parsed_results.append(yelp_dict)
        
        for rev in parsed_results:
            rev_tuple = (rev['rev_id'], rev['rev_rating'], rev['name'], rev['review_text'], rev['rev_date'])
            rev_list.append(rev_tuple)
        return rev_list

def create_tuple(data): 
    for rev in yelp_reviews:
        rev_tuple = (rev['rev_id'], rev['rev_rating'], rev['name'], rev['review_text'], rev['rev_date'])
            rev_list.append(rev_tuple)
    return rev_list
    
def db_insert_reviews(data):
        insert_statement = "INSERT INTO Plumb_Reviews (rev_id, rev_rating, name, review_text, rev_date) VALUES (%s, %s, %s, %s, %s)"
        cursor.executemany(insert_statement, data)
        cnx.commit()


cur = 0  
while cur < 438:
    url_params['offset'] = cur
    results = yelp_call(url_params, api_key)
    biz_id = parse_results_reviews(results)
    review_results = yelp_call_review(api_key, the_id)
    parsed_review_results = parse_review_results(review_results)
    db_insert_reviews(parsed_review_results)
    time.sleep(1) #Wait a second
    cur = 50 + cur
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-346-c6baa0ae5c7d> in <module>
#      78     results = yelp_call(url_params, api_key)
#      79     biz_id = parse_id_results(results)
# ---> 80     review_results = yelp_call_review(api_key)
#      81     parsed_review_results = parse_review_results
#      82     db_insert_reviews(parsed_review_results)
#
# <ipython-input-346-c6baa0ae5c7d> in yelp_call_review(api_key)
#      42 def yelp_call_review(api_key):
#      43     for i in biz_id:
# ---> 44         url = ('https://api.yelp.com/v3/businesses/{}/reviews'.format(biz_id[i]))
#      45         headers = {'Authorization': 'Bearer {}'.format(api_key)}
#      46         response = requests.get(url, headers=headers, params=url_params)
#
# TypeError: list indices must be integers or slices, not str

# %%
biz_id = ['tXtXY7r8NXPk0-MKJlrOjQ',
 '1M5qDSvsfNogoZeXYx2icg',
 'hlMkCkl-8wmFD57rD_JEJg']

api_key = "xZce1e9e3JthFVYS0eQm1Aa6thcOEaQ2N2hzi3PJsJrv6ga4hinQMYsPWTBYQYRikD7sN9H7HQJV9sDPBoIf-m2Ko-0rw5ouSZhGgUtQDYA5_5hEipYddHf7Ct2xXXYx"

length = len(biz_id)
for i in range(0,length):
    print(i)
# Out:
# 0
# 1
# 2

# %%
def yelp_call_review(api_key):
    length = len(biz_id)   
    for i in range(0,length):
        url = ('https://api.yelp.com/v3/businesses/%s/reviews'% biz_id[i])
        headers = {'Authorization': 'Bearer {}'.format(api_key)}
        response = requests.get(url, headers=headers, params=url_params)
        data = response.json()['reviews']
    return data

# %%
x = yelp_call_review(api_key)

def parse_review_results(results):
        parsed_results = []
        rev_list = []
        for result1 in results:
            for result in result1:
                yelp_dict = {}
                yelp_dict["rev_id"] = result['id']
                yelp_dict["rev_rating"] = result['rating']
                yelp_dict["name"] = result['user']
                yelp_dict["review_text"] = result['text']
                yelp_dict["rev_date"] = result['time_created']
                parsed_results.append(yelp_dict)
        
            for rev in parsed_results:
                rev_tuple = (rev['rev_id'], rev['rev_rating'], rev['name'], rev['review_text'], rev['rev_date'])
                rev_list.append(rev_tuple)
            return rev_list

previous_results = parse_review_results(results)
        
def parse_results_reviews(previous_results):
    yelp_reviews = []
    for result in previous_results:
        yelp_dict = {}
        the_id = result['biz_id']
        data = yelp_call_reviews(api_key,the_id)
        yelp_reviews.append(data)
        time.sleep(.5sec)
        
#         yelp_dict['id'] = data['id']
#         yelp_dict["reviews"] = data["reviews"]
#         yelp_reviews.append(yelp_dict)
#         time.sleep(.5sec)

# %%
def parse_results_for_id(results):
        parsed_results = []
        for result in results:
            yelp_dict = {}
            yelp_dict["biz_id"] = result['id']
            yelp_dict["biz_name"] = result['name']
            yelp_dict["rating"] = result['rating']
            yelp_dict["review_count"] = result['review_count']
            parsed_results.append(yelp_dict)
        return parsed_results

# %%
previous_results = parse_results_for_id(results1)
previous_results
# Out:
# [{'biz_id': 'tXtXY7r8NXPk0-MKJlrOjQ',
#   'biz_name': 'Friedman Irwin & Son',
#   'rating': 4.5,
#   'review_count': 50},
#  {'biz_id': '1M5qDSvsfNogoZeXYx2icg',
#   'biz_name': 'Pipe Monkeys Sewer and Drain',
#   'rating': 5.0,
#   'review_count': 27},
#  {'biz_id': 'hlMkCkl-8wmFD57rD_JEJg',
#   'biz_name': 'Dov Sewer and Drain',
#   'rating': 4.5,
#   'review_count': 57},
#  {'biz_id': 'a6TKGWUFop1T-nlEIi8aNA',
#   'biz_name': "Sam's Plumbing Services",
#   'rating': 4.5,
#   'review_count': 19},
#  {'biz_id': 'TYdz9vpLiXFF7-kbwbx1cQ',
#   'biz_name': 'Parkset Plumbing',
#   'rating': 4.5,
#   'review_count': 20},
#  {'biz_id': 'g5kfI33jirjUxeYPK6DU_w',
#   'biz_name': 'Michael Donahue Plumbing & Heating',
#   'rating': 5.0,
#   'review_count': 25},
#  {'biz_id': '3020UCNczgSJLYD1-JrDMw',
#   'biz_name': 'Four Season Piping & Mechanical',
#   'rating': 4.5,
#   'review_count': 24},
#  {'biz_id': 'QzpYYXgFsz7aCLgm1goDaA',
#   'biz_name': 'The Original 718 Sewer & Drain',
#   'rating': 4.5,
#   'review_count': 172},
#  {'biz_id': 'PvuChiGcd-T-KIPRl7SVqg',
#   'biz_name': 'MKC Plumbing',
#   'rating': 5.0,
#   'review_count': 38},
#  {'biz_id': 'ZnMyiLNJqInJbQ1n-zpSSA',
#   'biz_name': 'JPeral Piping & Heating Sewer Service',
#   'rating': 4.5,
#   'review_count': 45},
#  {'biz_id': 'r-UxNIwsZH1KSnMkkHhZvQ',
#   'biz_name': 'Franco Belli Plumbing & Heating & Sons',
#   'rating': 4.5,
#   'review_count': 32},
#  {'biz_id': 'dNdqqq7xqTzEYSDybMyS-Q',
#   'biz_name': 'JCA Mechanical',
#   'rating': 4.5,
#   'review_count': 127},
#  {'biz_id': 'han8zgVwsxnd_fHrco8P9w',
#   'biz_name': 'Vuksani Plumbing & Heating',
#   'rating': 5.0,
#   'review_count': 5},
#  {'biz_id': 'R5vfxUuI8FQI4Ptbgbu43g',
#   'biz_name': 'Empire Handyman',
#   'rating': 5.0,
#   'review_count': 13},
#  {'biz_id': 'p4f8SQpBDAUo2pl9TDnUeg',
#   'biz_name': 'The Clogfather Sewer & Drain',
#   'rating': 5.0,
#   'review_count': 3},
#  {'biz_id': 'BF1e6ud2EWwENkyyNnh7FQ',
#   'biz_name': 'ASAP Solutions',
#   'rating': 4.5,
#   'review_count': 69},
#  {'biz_id': 'DzgjPAeTGA8ncokuErTGMw',
#   'biz_name': '123 Backflow Testing',
#   'rating': 5.0,
#   'review_count': 2},
#  {'biz_id': 'BlVq-v2ZLBfCgPI902nCqw',
#   'biz_name': 'Taylor Group Plumbing, Heating, Mechanical & Sprinkler',
#   'rating': 5.0,
#   'review_count': 1},
#  {'biz_id': 'zp4qPlbQOkfnEjXCO323lg',
#   'biz_name': 'Zabivay',
#   'rating': 5.0,
#   'review_count': 60},
#  {'biz_id': '8E1bDQzKertDZ1r_yvUq9g',
#   'biz_name': 'A Real Good Plumber',
#   'rating': 3.0,
#   'review_count': 13},
#  {'biz_id': 'FGm82IPkwdIWJlmO5VITeg',
#   'biz_name': 'Joseph L Balkan Inc',
#   'rating': 4.0,
#   'review_count': 46},
#  {'biz_id': 'MXywrRCj-cnpnnnaEBRlxQ',
#   'biz_name': 'Star Cities Plumbing & Heating',
#   'rating': 4.5,
#   'review_count': 29},
#  {'biz_id': 'U4eItfkb9Mfa_vDa6d76Mg',
#   'biz_name': 'The Pump Guys',
#   'rating': 5.0,
#   'review_count': 1},
#  {'biz_id': 'CwBjwKBnIQiJYYaCBEcXIA',
#   'biz_name': 'Safeway Sewer & Drain Cleaning',
#   'rating': 5.0,
#   'review_count': 2},
#  {'biz_id': 'IidxRCySk_loNxS7_szt7Q',
#   'biz_name': 'Northside Sewer and  Drain',
#   'rating': 5.0,
#   'review_count': 2},
#  {'biz_id': 'AqpRoRQp3YKght_yIuv0QA',
#   'biz_name': 'SOS Plumbing & HVAC',
#   'rating': 5.0,
#   'review_count': 1},
#  {'biz_id': 'VHhpuWMw_e3S9fv6uag05w',
#   'biz_name': 'Empire Water Main & Sewer',
#   'rating': 5.0,
#   'review_count': 8},
#  {'biz_id': 'bhcw9zq-e1qz-Q3gMLIx0Q',
#   'biz_name': 'Bk Piping And Heating',
#   'rating': 4.5,
#   'review_count': 9},
#  {'biz_id': 'PF0upaxFu7Qzq2IUPFtQKw',
#   'biz_name': 'OC Piping Service',
#   'rating': 5.0,
#   'review_count': 12},
#  {'biz_id': 'zg267A7rvb27cXyY2pH0jA',
#   'biz_name': 'Kew Forest Plumbing & Heating',
#   'rating': 3.5,
#   'review_count': 27},
#  {'biz_id': '2rMHF-tMnF_I_PCN0MM-UQ',
#   'biz_name': 'One Planet Construction',
#   'rating': 4.0,
#   'review_count': 1},
#  {'biz_id': 'LnshTb2O2ZoXWBWWlR1w9g',
#   'biz_name': '1 Stop Plumbing & Handyman Svcs',
#   'rating': 3.5,
#   'review_count': 3},
#  {'biz_id': 'Tan2JA6FEoa_5zSZaRprBw',
#   'biz_name': 'A1 Construction',
#   'rating': 4.5,
#   'review_count': 41},
#  {'biz_id': 'NKN6DzIm3zEgOy4rtrJjKw',
#   'biz_name': 'Federico Plumbing',
#   'rating': 5.0,
#   'review_count': 10},
#  {'biz_id': 'dy2HBt06bbbcbOrdLUndIQ',
#   'biz_name': 'Stitch Coterie',
#   'rating': 5.0,
#   'review_count': 24},
#  {'biz_id': '0m1dRGzPNlx_JLKo6lRaTQ',
#   'biz_name': 'Hub Plumbing & Mechanical',
#   'rating': 4.5,
#   'review_count': 120},
#  {'biz_id': 'SGFRYzRsp3dTxDiCAbi-Pw',
#   'biz_name': 'J V MECH',
#   'rating': 4.5,
#   'review_count': 44},
#  {'biz_id': 'YGYTvJXmvIaQcENKbMiXIA',
#   'biz_name': 'Marcel Mechanic Plumbing',
#   'rating': 4.5,
#   'review_count': 9},
#  {'biz_id': 'WVhUiCyjymE14EGO39Jl7Q',
#   'biz_name': 'CPH Services Corporation',
#   'rating': 4.0,
#   'review_count': 3},
#  {'biz_id': 'TnShifQc06Waajnhs396XA',
#   'biz_name': 'CN Coterie',
#   'rating': 4.5,
#   'review_count': 15},
#  {'biz_id': 'EtKGVUVIzaBZykLo7JW4DQ',
#   'biz_name': 'Tim Golden Hands',
#   'rating': 5.0,
#   'review_count': 4},
#  {'biz_id': 'zO1ODFYMX-nbOMVDam5tjg',
#   'biz_name': 'Aurora Plumbing & Heating Contractors',
#   'rating': 3.5,
#   'review_count': 7},
#  {'biz_id': 'VQk9zaPs3YWKPwKkZz6gDw',
#   'biz_name': 'Mario Construction',
#   'rating': 5.0,
#   'review_count': 1},
#  {'biz_id': 'XjIl_1B4ONytdJfnn1IoQA',
#   'biz_name': 'Agalliu Contracting',
#   'rating': 4.5,
#   'review_count': 11},
#  {'biz_id': 'h0OoIDNxhcNpR3lkIhAmbg',
#   'biz_name': 'Big Benz Plumbing & Heating',
#   'rating': 3.0,
#   'review_count': 2},
#  {'biz_id': 'nshCt83YkUseutjNzidTNg',
#   'biz_name': '39.99 sewer service',
#   'rating': 2.0,
#   'review_count': 7},
#  {'biz_id': 'Rj6uRroFAzGU_KY7Q1czig',
#   'biz_name': 'Primary Plumbing & Heating',
#   'rating': 5.0,
#   'review_count': 17},
#  {'biz_id': 'eu8I4n9NI-rzJZVAIAk4Ig',
#   'biz_name': 'Nationwide Plumbers',
#   'rating': 4.5,
#   'review_count': 11},
#  {'biz_id': 'RgBMW-m8nAy4KWrkxgM4Kw',
#   'biz_name': 'Petri Plumbing & Heating',
#   'rating': 3.0,
#   'review_count': 92},
#  {'biz_id': 'Fn0aowwtFAO4lFNEL-KURg',
#   'biz_name': 'Meyerowitz Supply',
#   'rating': 5.0,
#   'review_count': 5}]

# %%
def yelp_call_review(api_key, the_id):
        url = ('https://api.yelp.com/v3/businesses/%s/reviews'% the_id)
        headers = {'Authorization': 'Bearer {}'.format(api_key)}
        response = requests.get(url, headers=headers, params=url_params)
        data = response.json()['reviews']
        return data

# %%
def parse_results_reviews(previous_results):
    yelp_reviews = []
    for result in previous_results:
        yelp_dict = {}
        the_id = result['biz_id']
        data = yelp_call_review(api_key,the_id)
        yelp_reviews.append(data)
        time.sleep(5)
        
def create_tuple(data): 
    for rev in yelp_reviews:
        rev_tuple = (rev['rev_id'], rev['rev_rating'], rev['name'], rev['review_text'], rev['rev_date'])
            rev_list.append(rev_tuple)
    return rev_list
# Out:
#   File "<ipython-input-496-4bc5846315ce>", line 10
#     create_tuple(data):
#                         ^
# SyntaxError: invalid syntax

# %%
parse_results_reviews(previous_results)

# %% [markdown]
# ## Part 3: Create ETL pipeline for the restaurant review data from the API

# %%
# write a SQL query to pull back all of the business ids 
# you will need these ids to pull back the reviews for each restaurant

# %%
def yelp_call_review(api_key, biz_ids):
    for i in biz_ids:
        url = ('https://api.yelp.com/v3/businesses/%s/reviews'% i)
        headers = {'Authorization': 'Bearer {}'.format(api_key)}
        response = requests.get(url, headers=headers, params=url_params)
        data = response.json()['reviews']
        time.sleep(.5)
        continue

# %%
new_biz_ids = biz_ids[0:3]

# %%
reviews = yelp_call_review(api_key, new_biz_ids)

# %%
soup.select

# %%
reviews
# Out:
# [{'id': '53kveCv7IK4AMbLkFnWyQw',
#   'url': 'https://www.yelp.com/biz/cilento-pipeline-plumbing-and-heating-oceanside?adjust_creative=kSJKHzaATCEw4bxY9tJGwA&hrid=53kveCv7IK4AMbLkFnWyQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=kSJKHzaATCEw4bxY9tJGwA',
#   'text': 'After Hurricane Sandy I put up a Baxi Luna tankless Boiler to replace the traditional one I lost in the storm. Well after 2 years the machine started to...',
#   'rating': 5,
#   'time_created': '2015-02-08 05:03:36',
#   'user': {'id': 'HwVIAJQbJiStL4Wyl4ocMw',
#    'profile_url': 'https://www.yelp.com/user_details?userid=HwVIAJQbJiStL4Wyl4ocMw',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/Z89EmKHBx01g5R4JiNUebw/o.jpg',
#    'name': 'Roz S.'}},
#  {'id': '4icZX_J2NbA3B26Ik57qNg',
#   'url': 'https://www.yelp.com/biz/cilento-pipeline-plumbing-and-heating-oceanside?adjust_creative=kSJKHzaATCEw4bxY9tJGwA&hrid=4icZX_J2NbA3B26Ik57qNg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=kSJKHzaATCEw4bxY9tJGwA',
#   'text': "I've had Cilento Plumbing at my house for several different issues. They are VERY professional and courteous. I highly recommend them for any and all...",
#   'rating': 5,
#   'time_created': '2019-01-11 11:11:39',
#   'user': {'id': 'Wbmjr_K9hwPG50h97jNlMw',
#    'profile_url': 'https://www.yelp.com/user_details?userid=Wbmjr_K9hwPG50h97jNlMw',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/sjvNY0C1_oeTlLHGHJ6etQ/o.jpg',
#    'name': 'John D.'}},
#  {'id': 'th8_IZ3U6XrQ67v9gHD_NA',
#   'url': 'https://www.yelp.com/biz/cilento-pipeline-plumbing-and-heating-oceanside?adjust_creative=kSJKHzaATCEw4bxY9tJGwA&hrid=th8_IZ3U6XrQ67v9gHD_NA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=kSJKHzaATCEw4bxY9tJGwA',
#   'text': 'Had an emergency with my hot water heater and gave Cilento Pipeline Plumbing a call. The absolute best ever! Extremely reliable and trustworthy. The owner,...',
#   'rating': 5,
#   'time_created': '2018-02-17 16:30:56',
#   'user': {'id': 'yZGqqjJIg3o3JWNusaF-lg',
#    'profile_url': 'https://www.yelp.com/user_details?userid=yZGqqjJIg3o3JWNusaF-lg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/NEe8-Y3u5PCXkAhJgn8Klw/o.jpg',
#    'name': 'Courtney S.'}}]

# %%
reviews = yelp_call_review(api_key, biz_ids)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-610-5ddef9cc2e5f> in <module>
# ----> 1 reviews = yelp_call_review(api_key, biz_ids)
#
# <ipython-input-609-cf757204758e> in yelp_call_review(api_key, biz_ids)
#       4         headers = {'Authorization': 'Bearer {}'.format(api_key)}
#       5         response = requests.get(url, headers=headers, params=url_params)
# ----> 6         data = response.json()['reviews']
#       7         time.sleep(.5)
#       8     return data
#
# KeyError: 'reviews'

# %%
def parse_review_results(results):
        parsed_results = []
        rev_list = []
        for result in results['reviews']:
            yelp_dict = {}
            yelp_dict["rev_id"] = result['id']
            yelp_dict["rev_rating"] = result['rating']
            yelp_dict["name"] = result['user']
            yelp_dict["review_text"] = result['text']
            yelp_dict["rev_date"] = result['time_created']
            parsed_results.append(yelp_dict)
        
        for rev in parsed_results:
            rev_tuple = (rev['rev_id'], rev['rev_rating'], rev['name'], rev['review_text'], rev['rev_date'])
            rev_list.append(rev_tuple)
        return rev_list

# %%
parse_review_results(reviews)
# Out:
# [('5uZVvDW8MxUH9I4sevqNSg',
#   5,
#   {'id': 'kyd4YipQY99I7uwxujFivA',
#    'profile_url': 'https://www.yelp.com/user_details?userid=kyd4YipQY99I7uwxujFivA',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/TCuThgpRAmZFOrtwk5rTHg/o.jpg',
#    'name': 'Dawn H.'},
#   'These guys are absolutely amazing!!! I highly recommend them. I had a pipe break on on my boiler, on a Saturday night.  They were very professional on the...',
#   '2018-03-16 17:40:09'),
#  ('zkkaCiG1q3Nkh7Wo9EeQLg',
#   5,
#   {'id': '-WEGyk8InhSENhgW-2BzkA',
#    'profile_url': 'https://www.yelp.com/user_details?userid=-WEGyk8InhSENhgW-2BzkA',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/PMbtMMNooplqqmHNLR-BPQ/o.jpg',
#    'name': 'Matt D.'},
#   'Prior to calling these guys I went through three different plumbers!!! Each one attempted to clear a clog that was causing my basement to flood.  Each one...',
#   '2018-02-20 17:02:01'),
#  ('t5ICb-3mR7lqUGu52iEMyg',
#   1,
#   {'id': 'rozR76USGkaCLDysQ5acTw',
#    'profile_url': 'https://www.yelp.com/user_details?userid=rozR76USGkaCLDysQ5acTw',
#    'image_url': None,
#    'name': 'Terry B.'},
#   "Not serious at all ; he does this as a side job because he works for the city ( if I'm not mistaken ) . Called that guy Mike once, he did good job ; second...",
#   '2019-01-16 07:40:33')]

# %%
def db_insert_reviews(data):
        insert_statement = "INSERT INTO Plumb_Reviews (rev_id, rev_rating, name, review_text, rev_date) VALUES (%s, %s, %s, %s, %s)"
        cursor.executemany(insert_statement, data)
        cnx.commit()

# %%
# write a function to insert the parsed data into the reviews table

# %%
# combine the functions above into a single script

# %% [markdown]
# ## Part 4: Write SQL queries that will answer the questions posed.

# %%
# create connection

# %%
# execute SQL queries

# %% [markdown]
# # Extra Reference help

# %% [markdown]
# ###  Pagination
#
# Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the API limits. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a maximum of 50 results per request and defaults to 20. Furthermore, any search will be limited to a total of 1000 results. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retriving 50 at a time. Processes such as these are often refered to as pagination.
#
# Now that you have an initial response, you can examine the contents of the json container. For example, you might start with ```response.json().keys()```. Here, you'll see a key for `'total'`, which tells you the full number of matching results given your query parameters. Write a loop (or ideally a function) which then makes successive API calls using the offset parameter to retrieve all of the results (or 5000 for a particularly large result set) for the original query. As you do this, be mindful of how you store the data.
#
# **Note: be mindful of the API rate limits. You can only make 5000 requests per day, and APIs can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use time.sleep(n) to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.**

# %% [markdown]
# ***Below is sample code that you can use to help you deal with the pagination parameter and bring all of the functions together.***
#
#
# ***Also, something might cause your code to break while it is running. You don't want to constantly repull the same data when this happens, so you should insert the data into the database as you call and parse it, not after you have all of the data***

# %%
def yelp_call(url_params, api_key):
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {'Authorization': 'Bearer {}'.format(api_key)}
    response = requests.get(url, headers=headers, params=url_params)
    
    data = response.json()['businesses']
    return data

# %%
def parse_results(results):
    
    return parsed_results

# %%
# Your code here; use a function or loop to retrieve all the results from your original request
import time



def all_results(url_params, api_key):
    num = response.json()['total']
    print('{} total matches found.'.format(num))
    cur = 0
    
    while cur < num and cur < 1000:
        url_params['offset'] = cur
        results = yelp_call(url_params, api_key)
        parsed_results = parse_results(results)
        db_insert(parsed)
        time.sleep(1) #Wait a second
        cur += 50

term = 'pizza'
location = 'Astoria NY'
url_params = {  'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit' : 50
             }
df = all_results(url_params, api_key)
print(len(df))
df.head()

# %% [markdown]
# ### Sample SQL Query
#
# Below is a SQL query to create a table.  Additionally here is a link to create a table with a foreign key.
#
# http://www.mysqltutorial.org/mysql-foreign-key/
#
# ```CREATE TABLE IF NOT EXISTS tasks (
#     task_id INT AUTO_INCREMENT,
#     title VARCHAR(255) NOT NULL,
#     start_date DATE,
#     due_date DATE,
#     status TINYINT NOT NULL,
#     priority TINYINT NOT NULL,
#     description TEXT,
#     PRIMARY KEY (task_id)
# )  ENGINE=INNODB;```

# %% [markdown]
# ### Using DB:
#
# For this lab, you can either store the data on one DB or put in on both of the partners DBs. If you decide to put it on one DB, you want to make sure both partners have access to it.  To do this you want to add a user to your DB.
#
# [how to add a new user](https://howchoo.com/g/mtm3zdq2nzv/how-to-add-a-mysql-user-and-grant-privileges)
